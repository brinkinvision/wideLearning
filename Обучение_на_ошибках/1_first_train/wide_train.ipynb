# %%
import widelearning as wdl

# %%
wdl.select_top('FOREST_train.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  3
# Количество НЕотсеченных сверху =  45
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  129
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  4
# TOP -  ['d ']
# OTHERS -  ['h ', 's ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  39
# Количество отсеченных снизу =  15
# Количество НЕотсеченных снизу =  119
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  20
# TOP -  ['h ']
# OTHERS -  ['d ', 's ', 'o ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  40
# Количество НЕотсеченных сверху =  12
# Количество отсеченных снизу =  27
# Количество НЕотсеченных снизу =  99
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  67
# TOP -  ['s ']
# OTHERS -  ['d ', 'h ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  29
# Количество НЕотсеченных сверху =  5
# Количество отсеченных снизу =  31
# Количество НЕотсеченных снизу =  113
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  60
# TOP -  ['o ']
# OTHERS -  ['d ', 'h ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('train_2.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  5
# Количество отсеченных снизу =  18
# Количество НЕотсеченных снизу =  95
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  18
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  16
# Количество НЕотсеченных сверху =  32
# Количество отсеченных снизу =  2
# Количество НЕотсеченных снизу =  68
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  18
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  3
# Количество НЕотсеченных сверху =  18
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  96
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  4
# TOP -  ['s ']
# OTHERS -  ['o ', 'd ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  21
# Количество НЕотсеченных сверху =  23
# Количество отсеченных снизу =  10
# Количество НЕотсеченных снизу =  64
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  31
# TOP -  ['h ']
# OTHERS -  ['o ', 'd ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'h'

# %%
wdl.select_top('train_3.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  23
# Количество отсеченных снизу =  8
# Количество НЕотсеченных снизу =  56
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  8
# TOP -  ['h ']
# OTHERS -  ['s ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  3
# Количество НЕотсеченных сверху =  18
# Количество отсеченных снизу =  3
# Количество НЕотсеченных снизу =  63
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  6
# TOP -  ['s ']
# OTHERS -  ['h ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  3
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  81
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['o ']
# OTHERS -  ['h ', 's ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  11
# Количество НЕотсеченных сверху =  27
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  48
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  12
# TOP -  ['d ']
# OTHERS -  ['h ', 's ', 'o ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1

# %%
# в качестве целевого выбираем класс 'd'

# %%
wdl.select_top('train_4.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  4
# Количество НЕотсеченных сверху =  23
# Количество отсеченных снизу =  6
# Количество НЕотсеченных снизу =  42
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  10
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  3
# Количество отсеченных снизу =  6
# Количество НЕотсеченных снизу =  64
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  8
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  15
# Количество отсеченных снизу =  2
# Количество НЕотсеченных снизу =  53
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  7
# TOP -  ['s ']
# OTHERS -  ['d ', 'o ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  14
# Количество НЕотсеченных сверху =  9
# Количество отсеченных снизу =  3
# Количество НЕотсеченных снизу =  49
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  17
# TOP -  ['h ']
# OTHERS -  ['d ', 'o ', 's ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1

# %%
# в качестве целевого выбираем класс 'h'

# %%
wdl.select_top('train_5.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  8
# Количество НЕотсеченных сверху =  1
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  48
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  9
# TOP -  ['h ']
# OTHERS -  ['s ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  7
# Количество НЕотсеченных сверху =  13
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  37
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  8
# TOP -  ['s ']
# OTHERS -  ['h ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  3
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  52
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['o ']
# OTHERS -  ['h ', 's ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  7
# Количество НЕотсеченных сверху =  17
# Количество отсеченных снизу =  3
# Количество НЕотсеченных снизу =  31
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  10
# TOP -  ['d ']
# OTHERS -  ['h ', 's ', 'o ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1

# %%
# в качестве целевого выбираем класс 'h'

# %%
wdl.select_top('train_6.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  1
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  47
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  2
# TOP -  ['h ']
# OTHERS -  ['s ', 'd ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  9
# Количество НЕотсеченных сверху =  10
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  29
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  10
# TOP -  ['s ']
# OTHERS -  ['h ', 'd ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  8
# Количество НЕотсеченных сверху =  16
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  24
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  9
# TOP -  ['d ']
# OTHERS -  ['h ', 's ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  6
# Количество НЕотсеченных снизу =  38
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  11
# TOP -  ['o ']
# OTHERS -  ['h ', 's ', 'd ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('train_7.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  24
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  13
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  25
# TOP -  ['d ']
# OTHERS -  ['s ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  8
# Количество отсеченных снизу =  24
# Количество НЕотсеченных снизу =  1
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  29
# TOP -  ['s ']
# OTHERS -  ['d ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  1
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  36
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  2
# TOP -  ['h ']
# OTHERS -  ['d ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'd'

# %%
wdl.select_top_binary('train_8.csv', 'class')
# Out:
# Количество отсеченных сверху =  12
# Количество отсеченных снизу =  1
# ===Верхняя категория:  s
# ===Нижняя категория:  h
# TOP -  ['s ']
# OTHER -  ['h ']
# СУММА отсеченных сверху и снизу =  13
# [9120.0, -4920.0, -6696.0, -16166.0, 10800.0, 21459.0, 5320.0, -530.0, 3014.0, 13794.0, 9125.0, 14076.0, 35169.0, -3324.0, -2128.0, 19476.0, 6570.0, 6734.0, -11732.0, -3284.0, 6096.0, -25678.0, -24455.0, -28355.0, -54928.0, -17082.0, -28536.0]
# DISTANCE =  72340578.0
# +++++++++++++++++++++++++++++++++++++++
#
# Количество отсеченных сверху =  5
# Количество отсеченных снизу =  7
# ===Верхняя категория:  s
# ===Нижняя категория:  s
# TOP -  ['h ']
# OTHER -  ['s ']
# СУММА отсеченных сверху и снизу =  12
# [-24491.0, -92290.0, -89928.0, -23929.333333333332, -63250.0, -45820.666666666664, -33028.33333333333, -82724.16666666666, -70121.16666666666, 25368.166666666664, 79408.75000000001, 87416.25, 20090.916666666664, 65581.0, 48622.58333333333, 17675.666666666668, 59178.166666666664, 50860.83333333333, -28177.333333333332, -11234.166666666666, -973.3333333333333, 5588.833333333333, -12841.083333333332, -6973.083333333334, -12844.666666666668, -10770.75, -19064.666666666664]
# DISTANCE =  5719610.333334923
# +++++++++++++++++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1478: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_classes_allcut.drop(all_classes_allcut.columns[0], axis=1, inplace=True)
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1478: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_classes_allcut.drop(all_classes_allcut.columns[0], axis=1, inplace=True)

# %%
# в качестве целевого выбираем класс 's'

# %%
wdl.scale_weights('class', 'data/', 'weights/')
# Out:
# I =  0
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0          38    o  -1368 -2640 -3132 -3151  4800  5909  1330  5035  ...
# 1          63    o  -2964 -2760 -3240 -2740  7500  8086 -4180   795  ...
# 2          82    o  -1824 -3000 -3348 -2740  6300  6531 -2090  1325  ...
# 3          90    o   2736   720   432   548  5700  5909 -1330 -1325  ...
# 4         136    o  -3648 -3000 -2592 -5069  5100  6220 -7980  1325  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -1498                 -512                  -51
# 1                -2030                -2160                -1377
# 2                -1785                 -328                 -423
# 3                -1099                 -464                 1011
# 4                -1183                 -319                 -369
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2184                -2280                 -340
# 1                -1776                -2591                -2144
# 2                -1296                 -876                 -663
# 3                -2088                -1020                  112
# 4                -1488                 -888                -2236
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                 -414                -1424   38  6.927984e+09
# 1                -1917                -2576   63  6.376830e+09
# 2                 -648                -1216   82  5.915395e+09
# 3                 -630                 -960   90  5.280871e+09
# 4                -1007                -1856  136  4.917986e+09
#
# [5 rows x 31 columns]
# LENGTH_data =  178
# LABEL =  o
# UP =  29
# DOWN =  31
# -3826982992.020833
# -12996807525.569445
# [5.224236642486173e-06, 2.8438203193449453e-05, 2.432663778721993e-05, 2.0870779826669866e-06, 5.220383424444316e-05, 4.945175504805233e-05, 1.097591582630567e-06, 3.7612224611077565e-05, 4.256244655922866e-05, -4.059865034908483e-06, -2.354573104777476e-05, -2.1897756341868266e-05, -2.3044122031174896e-06, -5.2046512683290796e-05, -4.7115193314212964e-05, -9.395823795792243e-07, -2.8838453188287896e-05, -3.1287161136850215e-05, 6.394948490128026e-07, 4.708408281948826e-07, 1.5271405750325609e-06, 1.0597288685541746e-06, 2.7618455289120118e-06, 3.432199444113803e-06, 2.3009346132495244e-06, 1.4444236160302418e-06, 9.568643048377111e-07, 1.834690560984996]
# ++++++++++++++++++++++++++++
#
# I =  1
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6   b7    b8  ...  \
# 0          91    h   5244 -7440 -6912  1096 -6900 -4665  950 -7155  ...
# 1          89    h   3648 -7440 -6912   548 -6600 -4976 -570 -6890  ...
# 2         112    h   2736 -7680 -7452   411 -7500 -6220 -950 -7420  ...
# 3          94    h   2964 -7440 -7020     0 -6900 -4976  380 -7155  ...
# 4          61    h   3648 -7680 -7020   959 -5700 -3732  950 -6360  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -2303                -3200                 -525
# 1                -2821                -3664                  -78
# 2                 -616                -1016                 -144
# 3                -1862                -3856                 1149
# 4                -2604                -3176                -4704
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2544                -4248                -4324
# 1                -4224                -5448                -2148
# 2                -2016                -1920                -2400
# 3                -2856                -5160                -1016
# 4                -4728                -6780                -5792
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0          46    o   -456 -5280 -5724  -411   300  1555 -2850 -4505  ...
# 1          40    o  -2052 -5520 -5184   137  -600  1866  -760 -5830  ...
# 2           7    o   1140 -6240 -6480  -411 -1500     0  2850 -5830  ...
# 3          39    o  -3876 -5160 -5832 -8083 -5400 -7153 -6460   265  ...
# 4          47    o  -5472 -5880 -6372 -2329 -2400 -2799 -1140 -5565  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                 -826                   64                 -129
# 1                -1603                -1304                 -255
# 2                 -938                 -360                 -366
# 3                -2485                -2464                  336
# 4                 -840                 -624                  618
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -1344                 -912                -2544
# 1                -1536                 -924                -1699
# 2                -1440                -1032                -2812
# 3                -3264                -3072                 -644
# 4                 -672                  684                 1564
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                 -558                -1800  154 -1.999004e+08
# 1                -1179                -1776  122 -2.801321e+08
# 2                 -792                -2031  157 -3.094305e+08
# 3                -1404                -2024   56 -3.505947e+08
# 4                 -846                 -896   61 -4.027017e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  49
# LABEL =  o
# UP =  5
# DOWN =  6
# -420453370.7045454
# -656326823.0795455
# [3.3699888694008794e-05, 3.304545456922977e-05, 2.5578430580143515e-05, -1.3570065429531288e-05, 0.00010128697761597375, 8.576266705705969e-05, -2.0174531367230392e-05, 0.00010499466682703034, 0.000134591816264106, -2.2068073684685794e-05, -2.5905454935193585e-05, -2.1552966966330554e-05, 1.3597429871733513e-06, -0.0001071059684380665, -9.719849870216e-05, 1.0298858342333498e-05, -8.337444499923102e-05, -0.00010272072022149669, -1.6439670421311077e-05, 1.1272801235923917e-05, 1.3589336163476479e-05, 9.7560017670972e-06, 7.509034189086814e-06, 3.140570781783269e-05, -4.708803839509746e-06, 6.862115650546445e-06, 4.5646587495996314e-06, 4.565075819012421]
# ++++++++++++++++++++++++++++
#
# I =  6
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0           3    d   -684 -2760 -3024 -3151 -2400 -3110   570 -6890  ...
# 1          11    d  -2736 -5760 -5832  3014 -3900   311  3040 -6890  ...
# 2          10    d  -1596 -4920 -5724 -1918 -2400 -3732  3610 -6360  ...
# 3           2    d  -2508 -4800 -5724 -1096 -1800  -933  2090 -6360  ...
# 4           9    d  -3192 -5040 -5940  -959 -2400 -3110  3420 -6625  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -2296                -2944                  663
# 1                -3185                -4064                 -129
# 2                -2429                -3680                 -714
# 3                -1708                -1208                 -951
# 4                -1911                 -648                -1083
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2784                -3300                 -612
# 1                -2592                -2184                -1427
# 2                -3528                -4008                -2100
# 3                -1968                -2028                 -880
# 4                -2040                -2087                -1520
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -1305                -2008  194 -4.826802e+08
# 1                -1935                -2512  129 -4.845135e+08
# 2                -1089                -1792  158 -4.968021e+08
# 3                -1034                -1632   41 -5.715850e+08
# 4                -2060                -2472   86 -6.640421e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  38
# LABEL =  d
# UP =  24
# DOWN =  1
# -1696704019.2857141
# -2673747540.928572
# [-6.493993507111717e-05, 0.0001145379596196512, 8.640878424247217e-05, 3.2250354566618705e-05, 9.913288478110123e-05, 7.193743005615247e-05, 0.00016318325573568712, 6.974393221325231e-06, -2.6521409593915028e-05, 3.1805572508353094e-05, -0.00010525865372031806, -9.595215207383271e-05, -2.182648786777761e-05, -0.00010044471404696564, -7.530473143743384e-05, -9.000125471307928e-05, -7.714234514824382e-07, 2.2664292336502897e-05, 1.7897725900125418e-05, -4.701793769772674e-05, -6.887542286871026e-05, -3.559747845807739e-05, -6.772062711059649e-05, -8.187937641835862e-05, 5.116894448081748e-06, -2.424076838917224e-05, -1.839748430747322e-05, 4.47313908070907]
# ++++++++++++++++++++++++++++
#
# I =  7
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0           0    s  -2964 -7800 -7560 -2740 -3300 -2799 -4750 -7155  ...
# 1           3    s  -2964 -7920 -7560 -2329 -4800 -3421 -4560 -7685  ...
# 2           1    s  -2280 -7680 -7560 -2740 -4200 -3732 -1900 -6625  ...
# 3           8    s  -2964 -7560 -7668 -2740 -6000 -4976 -3610 -6625  ...
# 4           2    s  -2280 -7560 -7452 -2603 -4200 -2488  -570 -6625  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                  167                  736                -4761
# 1                 -280                 -576                -2556
# 2                -1449                -2120                  191
# 3                -1666                -1576                -1380
# 4                  280                   80                 1701
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -5111                -5448                -5344
# 1                -5040                -3828                -4024
# 2                -2496                -1344                -3204
# 3                 -144                -2160                -3172
# 4                  -96                  408                -2676
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -2664                -3000  190  1.255023e+09
# 1                -2925                -3544  185  1.045403e+09
# 2                -1287                -2208  167  7.362097e+08
# 3                 -189                -2160    6  6.711020e+08
# 4                -1170                -2304  174  5.792803e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  13
# LABEL =  s
# UP =  12
# DOWN =  1
# -257175817.0
# -329516395.0
# [0.00025214064504709927, -0.00013602324272277724, -0.00018512431570563343, -0.0004469414109464262, 0.00029858760597682813, 0.0005932769848756254, 0.00014708204294414126, -1.4652910293307305e-05, 8.332805966797777e-05, 0.00038136272563373767, 0.00025227888004986635, 0.0003891591797897993, 0.0009723173624628767, -9.189862983953488e-05, -5.8832817177656504e-05, 0.0005384529827782133, 0.00018164079363590377, 0.000186174901726663, -0.00032435461049260623, -9.079274981739847e-05, 0.00016853611537358742, -0.0007099196802104622, -0.0006761073985336418, -0.0007839307006919408, -0.001518594446397705, -0.0004722660634533498, -0.0007889348077921081, 8.110139954922671]
# ++++++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# [0.00025214064504709927,
#  -0.00013602324272277724,
#  -0.00018512431570563343,
#  -0.0004469414109464262,
#  0.00029858760597682813,
#  0.0005932769848756254,
#  0.00014708204294414126,
#  -1.4652910293307305e-05,
#  8.332805966797777e-05,
#  0.00038136272563373767,
#  0.00025227888004986635,
#  0.0003891591797897993,
#  0.0009723173624628767,
#  -9.189862983953488e-05,
#  -5.8832817177656504e-05,
#  0.0005384529827782133,
#  0.00018164079363590377,
#  0.000186174901726663,
#  -0.00032435461049260623,
#  -9.079274981739847e-05,
#  0.00016853611537358742,
#  -0.0007099196802104622,
#  -0.0006761073985336418,
#  -0.0007839307006919408,
#  -0.001518594446397705,
#  -0.0004722660634533498,
#  -0.0007889348077921081,
#  8.110139954922671]

# %%
wdl.check_test('data/train_1.csv', 'all_weights/weights.txt', 'FOREST_test.csv', 'class')
# Out:
# Ошибок =  2 из  20
# Экземпляры №: ['12', '92']

# %%
wdl.check_test('data/train_1.csv', 'all_weights/weights.txt', 'data/train_1.csv', 'class')
# Out:
# Ошибок =  0 из  178
# Экземпляры №: []
