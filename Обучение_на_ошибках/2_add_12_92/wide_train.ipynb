# %%
import widelearning as wdl

# %%
wdl.select_top('data/train_1.csv', 'class')
# Out:
# D:\ANACONDA\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  3
# Количество НЕотсеченных сверху =  45
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  131
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  4
# TOP -  ['d ']
# OTHERS -  ['h ', 's ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  6
# Количество НЕотсеченных сверху =  38
# Количество отсеченных снизу =  16
# Количество НЕотсеченных снизу =  120
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  22
# TOP -  ['h ']
# OTHERS -  ['d ', 's ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  40
# Количество НЕотсеченных сверху =  12
# Количество отсеченных снизу =  28
# Количество НЕотсеченных снизу =  100
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  68
# TOP -  ['s ']
# OTHERS -  ['d ', 'h ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  29
# Количество НЕотсеченных сверху =  7
# Количество отсеченных снизу =  33
# Количество НЕотсеченных снизу =  111
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  62
# TOP -  ['o ']
# OTHERS -  ['d ', 'h ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('data/train_2.csv', 'class')
# Out:
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  7
# Количество отсеченных снизу =  15
# Количество НЕотсеченных снизу =  96
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  15
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  17
# Количество НЕотсеченных сверху =  31
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  69
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  18
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  17
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  98
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['s ']
# OTHERS -  ['o ', 'd ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  19
# Количество НЕотсеченных сверху =  25
# Количество отсеченных снизу =  9
# Количество НЕотсеченных снизу =  65
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  28
# TOP -  ['h ']
# OTHERS -  ['o ', 'd ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'h'

# %%
wdl.select_top('data/train_3.csv', 'class')
# Out:
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  25
# Количество отсеченных снизу =  5
# Количество НЕотсеченных снизу =  60
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  5
# TOP -  ['h ']
# OTHERS -  ['s ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  17
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  70
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['s ']
# OTHERS -  ['h ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  2
# Количество отсеченных снизу =  6
# Количество НЕотсеченных снизу =  77
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  11
# TOP -  ['o ']
# OTHERS -  ['h ', 's ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  13
# Количество НЕотсеченных сверху =  26
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  50
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  14
# TOP -  ['d ']
# OTHERS -  ['h ', 's ', 'o ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'd'

# %%
wdl.select_top('data/train_4.csv', 'class')
# Out:
# Количество отсеченных сверху =  3
# Количество НЕотсеченных сверху =  23
# Количество отсеченных снизу =  6
# Количество НЕотсеченных снизу =  44
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  9
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  7
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  8
# Количество НЕотсеченных снизу =  61
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  15
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  13
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  57
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  6
# TOP -  ['s ']
# OTHERS -  ['d ', 'o ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  21
# Количество НЕотсеченных сверху =  4
# Количество отсеченных снизу =  2
# Количество НЕотсеченных снизу =  49
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  23
# TOP -  ['h ']
# OTHERS -  ['d ', 'o ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('data/train_5.csv', 'class')
# Out:
# Количество отсеченных сверху =  26
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  8
# Количество НЕотсеченных снизу =  27
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  34
# TOP -  ['d ']
# OTHERS -  ['s ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  10
# Количество НЕотсеченных сверху =  8
# Количество отсеченных снизу =  2
# Количество НЕотсеченных снизу =  41
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  12
# TOP -  ['s ']
# OTHERS -  ['d ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  16
# Количество НЕотсеченных сверху =  1
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  43
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  17
# TOP -  ['h ']
# OTHERS -  ['d ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'd'

# %%
wdl.select_top_binary('data/train_6.csv', 'class')
# Out:
# Количество отсеченных сверху =  16
# Количество отсеченных снизу =  8
# ===Верхняя категория:  s
# ===Нижняя категория:  h
# TOP -  ['s ']
# OTHER -  ['h ']
# СУММА отсеченных сверху и снизу =  24
# [-53352.0, -70560.0, -70740.0, -42333.0, -44700.0, -41363.0, -58710.0, -60685.0, -58910.0, 54971.0, 60072.0, 68937.0, 31219.0, 46407.0, 44286.0, 34380.0, 42282.0, 42042.0, -31399.0, 19403.0, 24175.0, 17435.0, 21841.0, 16536.0, -22519.0, 10450.0, 2048.0]
# DISTANCE =  43545264.0
# +++++++++++++++++++++++++++++++++++++++
#
# Количество отсеченных сверху =  6
# Количество отсеченных снизу =  3
# ===Верхняя категория:  s
# ===Нижняя категория:  s
# TOP -  ['h ']
# OTHER -  ['s ']
# СУММА отсеченных сверху и снизу =  9
# [-5814.0, -134820.0, -129654.0, -23016.0, -94350.0, -68264.5, -15675.0, -119780.0, -93982.0, 3646.0, 117174.0, 125436.0, 27132.5, 100864.5, 76681.5, 8026.5, 90402.0, 72714.0, -39777.5, -39543.5, -35815.0, -12117.5, -42035.5, -41625.0, -20571.5, -27134.5, -38600.0]
# DISTANCE =  129917136.0
# +++++++++++++++++++++++++++++++++++++++
# D:\ANACONDA\lib\site-packages\widelearning.py:1416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\lib\site-packages\widelearning.py:1417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\lib\site-packages\widelearning.py:1478: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\lib\site-packages\widelearning.py:1489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# в качестве целевого выбираем класс 's'

# %%
wdl.select_top_binary('data/train_7.csv', 'class')
# Out:
# Количество отсеченных сверху =  1
# Количество отсеченных снизу =  2
# ===Верхняя категория:  h
# ===Нижняя категория:  s
# TOP -  ['h ']
# OTHER -  ['s ']
# СУММА отсеченных сверху и снизу =  3
# [-684.0, -15360.0, -14472.0, -1849.5, -12900.0, -8397.0, -3610.0, -13382.5, -10138.0, -1271.0, 12699.0, 13322.5, 734.5, 13501.5, 8996.0, 937.5, 9612.0, 7409.0, 1894.0, -2534.0, -172.0, 6282.0, -2460.0, -251.0, 4696.0, -234.0, -540.0]
# DISTANCE =  13083917.5
# +++++++++++++++++++++++++++++++++++++++
#
# Количество отсеченных сверху =  2
# Количество отсеченных снизу =  1
# ===Верхняя категория:  s
# ===Нижняя категория:  h
# TOP -  ['s ']
# OTHER -  ['h ']
# СУММА отсеченных сверху и снизу =  3
# [684.0, -7680.0, -7236.0, 0.0, -5100.0, -2799.0, -380.0, -6095.0, -3836.0, 395.0, 6504.0, 7250.0, 818.0, 5826.0, 4711.0, 339.0, 4170.0, 2746.0, 5756.0, -889.0, 5464.0, 4761.0, 2856.0, 6371.0, 5948.0, 207.0, 2016.0]
# DISTANCE =  74140288.0
# +++++++++++++++++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'h'

# %%
wdl.scale_weights('class', 'data/', 'weights/')
# Out:
# I =  0
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0.1 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0            38    o  -1368 -2640 -3132 -3151  4800  5909  1330  5035  ...
# 1            63    o  -2964 -2760 -3240 -2740  7500  8086 -4180   795  ...
# 2            82    o  -1824 -3000 -3348 -2740  6300  6531 -2090  1325  ...
# 3            90    o   2736   720   432   548  5700  5909 -1330 -1325  ...
# 4           136    o  -3648 -3000 -2592 -5069  5100  6220 -7980  1325  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -1498                 -512                  -51
# 1                -2030                -2160                -1377
# 2                -1785                 -328                 -423
# 3                -1099                 -464                 1011
# 4                -1183                 -319                 -369
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2184                -2280                 -340
# 1                -1776                -2591                -2144
# 2                -1296                 -876                 -663
# 3                -2088                -1020                  112
# 4                -1488                 -888                -2236
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                 -414                -1424   38  7.173453e+09
# 1                -1917                -2576   63  6.528307e+09
# 2                 -648                -1216   82  6.069035e+09
# 3                 -630                 -960   90  5.436115e+09
# 4                -1007                -1856  136  4.959633e+09
#
# [5 rows x 31 columns]
# LENGTH_data =  180
# LABEL =  o
# UP =  29
# DOWN =  33
# -4008155593.875
# -13429015949.25
# [5.0823383633621565e-06, 2.886360584305425e-05, 2.4538523158142923e-05, 3.206554270042308e-06, 5.2160841097664236e-05, 4.983138294074769e-05, 2.89410934580345e-06, 3.800236777692361e-05, 4.3263033802158124e-05, -3.943641939114714e-06, -2.3870006720957148e-05, -2.204517338817226e-05, -3.0342239372745873e-06, -5.195247371655981e-05, -4.735522905245757e-05, -1.862515666097203e-06, -2.9028134340615056e-05, -3.168181978514417e-05, 1.1526548096856654e-06, 1.1670908585039037e-07, 1.1184753411601303e-06, 1.1274447979626387e-06, 2.416286744661538e-06, 3.0409112245948005e-06, 2.2245314344398646e-06, 6.36884506686987e-07, 2.5252470690139035e-07, 1.8509107327099223]
# ++++++++++++++++++++++++++++
#
# I =  1
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0.1 class    b1    b2    b3    b4    b5    b6   b7    b8  ...  \
# 0            90    h   5244 -7440 -6912  1096 -6900 -4665  950 -7155  ...
# 1            88    h   3648 -7440 -6912   548 -6600 -4976 -570 -6890  ...
# 2           110    h   2736 -7680 -7452   411 -7500 -6220 -950 -7420  ...
# 3            92    h   2964 -7440 -7020     0 -6900 -4976  380 -7155  ...
# 4            97    h   3192 -7680 -7236   822 -7200 -5598  190 -6890  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -2303                -3200                 -525
# 1                -2821                -3664                  -78
# 2                 -616                -1016                 -144
# 3                -1862                -3856                 1149
# 4                -1274                 -936                 -945
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2544                -4248                -4324
# 1                -4224                -5448                -2148
# 2                -2016                -1920                -2400
# 3                -2856                -5160                -1016
# 4                -3072                -1716                -2948
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -2853                -4504  178  6.359925e+09
# 1                -1107                -2712  171  6.000025e+09
# 2                 2025                  920  104  5.887176e+09
# 3                -2267                -3032  184  5.789439e+09
# 4                 -954                 -760  117  5.703085e+09
#
# [5 rows x 31 columns]
# LENGTH_data =  118
# LABEL =  h
# UP =  19
# DOWN =  9
# 5211246742.445946
# 12742548.094593648
# [8.464979691705959e-05, -2.8651069064163203e-05, -1.7341121315213275e-05, 3.579976783426732e-05, -5.305476250362423e-05, -3.52514188307805e-05, 8.937706110382419e-06, -8.139659500521737e-06, 8.042874903198187e-06, -7.807754255030995e-05, 2.2245068342300384e-05, 1.2787378976336039e-05, -2.7991471843361742e-05, 5.185044518183552e-05, 3.020696361035074e-05, -5.81090230394038e-06, 5.953708455599353e-06, -6.662249069138466e-06, -8.181875386333217e-07, -3.2958129217081704e-06, -5.8721465323713815e-06, -3.5708192635660885e-06, -1.0715452415110512e-05, -9.429874712135318e-06, 1.6228368794029605e-06, 3.1415377744703467e-06, 2.030958435585782e-06, -1.0049023902331133]
# ++++++++++++++++++++++++++++
#
# I =  2
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0.1 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0            59    d  -2736 -4440 -5400 -1507  -300  -622  5700 -6360  ...
# 1            51    d  -1824 -5040 -5616 -3014   600 -1555  2850 -6360  ...
# 2            61    d  -3420 -5040 -5616 -1644 -2100  -933  1520 -6625  ...
# 3            52    d  -2964 -4920 -5616 -3425 -2100 -1866  1140 -6890  ...
# 4            39    d  -2736 -5160 -5940 -1370 -2100 -1244  3420 -6095  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -2688                -2368                -1305
# 1                -3164                -4656                 -326
# 2                -1337                 -840                 -945
# 3                -2478                -2664                -1884
# 4                -2429                -2160                -1350
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2592                -3828                -2824
# 1                -3984                -4872                -2260
# 2                -2160                -1716                -3060
# 3                -2328                -3624                -2772
# 4                -2232                -3720                -3036
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -3240                -4152   24  1.151872e+09
# 1                -3501                -4128   21  7.593582e+08
# 2                -1413                -2416  146  4.144680e+08
# 3                -2223                -3096   50  4.071558e+08
# 4                -2457                -3456    4  3.460231e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  90
# LABEL =  d
# UP =  13
# DOWN =  1
# 65206363.52941229
# -3857698646.382351
# [-6.0075767528479e-05, 3.704937440579457e-05, 2.49686512447638e-05, -9.589472123399763e-06, 4.55604740143137e-05, 3.465846917256843e-05, 3.750461926857584e-05, -5.24521254943618e-06, -2.5004938878753636e-05, 5.701174167963197e-05, -3.2364161021227585e-05, -2.3926086527390438e-05, 1.0230953520955162e-05, -4.551219046826112e-05, -3.14088665641107e-05, -1.6803873617496214e-05, 3.972746177380292e-06, 1.886057274065423e-05, -1.2710358595424215e-05, -9.107776274520153e-06, -1.3042195512859959e-05, -1.815164432752601e-05, -1.3080912319042481e-05, -2.0549237281727133e-05, -1.6381917410689084e-05, -1.228249440192618e-05, -1.27823340678007e-05, 0.96675608337971]
# D:\ANACONDA\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# ++++++++++++++++++++++++++++
#
# I =  3
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0.1 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0             1    o  -1140 -4800 -5400 -2055   300  -311 -1710 -3710  ...
# 1             3    o   -456 -5280 -5724  -411   300  1555 -2850 -4505  ...
# 2             2    o  -1824 -3240 -4104  4247 -3900     0  8170 -3445  ...
# 3             0    o  -2052 -5520 -5184   137  -600  1866  -760 -5830  ...
# 4             6    o   1140 -6240 -6480  -411 -1500     0  2850 -5830  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -3010                -4808                 -249
# 1                 -826                   64                 -129
# 2                -2520                 -776                 -411
# 3                -1603                -1304                 -255
# 4                 -938                 -360                 -366
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -3816                -4728                -2616
# 1                -1344                 -912                -2544
# 2                -2640                -2052                 -440
# 3                -1536                 -924                -1699
# 4                -1440                -1032                -2812
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -4058                -4720   12 -3.384022e+08
# 1                 -558                -1800  154 -3.484417e+08
# 2                -2313                -2608   92 -3.543144e+08
# 3                -1179                -1776  122 -4.165890e+08
# 4                 -792                -2031  157 -5.199715e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  76
# LABEL =  o
# UP =  7
# DOWN =  8
# -636454648.188406
# -1101317179.514493
# [-1.3377680904838004e-05, 4.755777159301439e-05, 3.317221909699024e-05, 1.9305691788112437e-06, 8.737505943634758e-05, 8.078598355618157e-05, 1.1396855322754304e-05, 8.078342708901765e-05, 9.60842571826055e-05, 2.0957107223188176e-05, -3.8827810345156245e-05, -2.787808736466846e-05, -4.371995320415595e-06, -8.958621647462045e-05, -8.192411026701557e-05, -4.310265991334044e-06, -6.227154953175094e-05, -7.085279921409436e-05, -1.0571116428787599e-05, -3.3224096674561744e-06, -6.931393068709147e-06, -8.810458787094739e-08, -6.007697835361516e-06, 3.093449974135502e-06, -1.2222469511005694e-05, -1.6969143153089043e-05, -1.593639277169732e-05, 3.7382488598202475]
# ++++++++++++++++++++++++++++
#
# I =  4
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0.1 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0             0    d  -3648 -5400 -5940  -822 -1800  -933  1520 -6360  ...
# 1             8    d  -2508 -4920 -5832 -2603 -1800 -2799  2850 -6625  ...
# 2             3    d   -684 -2760 -3024 -3151 -2400 -3110   570 -6890  ...
# 3             2    d  -1140 -4560 -5400   411 -2400 -1866  5890 -6625  ...
# 4             9    d  -3192 -5040 -5940  -959 -2400 -3110  3420 -6625  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -1610                 -471                  153
# 1                -1148                -1072                  249
# 2                -2296                -2944                  663
# 3                -2058                 -768                -1266
# 4                -1911                 -648                -1083
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -1464                 -420                  840
# 1                -2160                -1836                 -172
# 2                -2784                -3300                 -612
# 3                -2424                -2316                -1696
# 4                -2040                -2087                -1520
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -1719                -1864   81 -3.317815e+08
# 1                -1098                -1912   94 -4.801826e+08
# 2                -1305                -2008  194 -4.899387e+08
# 3                -2511                -2928  100 -5.046271e+08
# 4                -2060                -2472   86 -5.094171e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  61
# LABEL =  d
# UP =  26
# DOWN =  8
# -1135250802.5857148
# -2242008612.5142865
# [-0.00015474078420067738, 9.938527434337915e-05, 6.966820372056365e-05, -1.3503173614927879e-05, 9.528991455652214e-05, 6.50958780523276e-05, 7.087626257448295e-05, -2.5448850717874735e-06, -5.15228478843031e-05, 0.00012616542677714034, -9.287555229791128e-05, -7.664100294616665e-05, 4.650649682314004e-06, -0.00010038985597944667, -7.328153780179663e-05, -3.994075529495994e-05, -4.4092754134844976e-07, 3.511197914687871e-05, 1.2560239225273708e-05, -1.218126871549645e-05, -1.1903391428899575e-05, -7.258885818883049e-06, -1.9748958705902346e-05, -1.513114625032108e-05, 1.0856214333626828e-05, -1.9400037356437148e-05, -1.4247432456677057e-05, 3.0514891196638256]
# ++++++++++++++++++++++++++++
#
# I =  5
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0.1 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0             6    s  -4104 -7320 -7128 -4521 -5700 -6220 -2660 -6890  ...
# 1            13    s  -2964 -7560 -7668 -2740 -6000 -4976 -3610 -6625  ...
# 2            17    s  -3192 -7440 -7344 -3699 -5700 -4976 -5130 -6095  ...
# 3            11    s  -3420 -7800 -7560 -3562 -5400 -5909 -4560 -6890  ...
# 4             7    s  -3876 -7920 -7884 -2192 -6300 -4665 -2090 -6890  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                  112                -2096                  129
# 1                -1666                -1576                -1380
# 2                 -567                 -984                 -885
# 3                 -966                -1824                -2406
# 4                -1680                  864                 1365
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -1776                -4140                -5036
# 1                 -144                -2160                -3172
# 2                 1368                 -528                -1704
# 3                 -744                -3276                -1480
# 4                  384                  852                -2480
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                  792                  168   51  5.202230e+09
# 1                 -189                -2160    6  5.053176e+09
# 2                  999                -1000   22  5.016176e+09
# 3                -2619                -2912  120  4.999327e+09
# 4                -2538                -3944  116  4.942358e+09
#
# [5 rows x 31 columns]
# LENGTH_data =  27
# LABEL =  s
# UP =  16
# DOWN =  8
# 4107294482.0
# 3693820804.0
# [-0.00025806721365223155, -0.00034130346744829545, -0.00034217413955913296, -0.00020476756926712998, -0.00021621690752464295, -0.00020007561400317241, -0.00028398422015149413, -0.0002935374280342944, -0.00028495163360798024, 0.00026589842558248655, 0.00029057230579016447, 0.0003334529072489108, 0.0001510084034901975, 0.0002244737813757518, 0.00021421436166971672, 0.0001662983731699603, 0.00020452087883572604, 0.00020335998268794273, -0.000151879075601035, 9.385361648099882e-05, 0.00011693610155275712, 8.433426806917562e-05, 0.00010564638651556436, 7.998574458227061e-05, -0.00010892591813305223, 5.0547353101398634e-05, 9.906313794417647e-06, -18.86725975818949]
# ++++++++++++++++++++++++++++
#
# I =  6
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0.1 class   b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0            16    h  -684 -7680 -7236 -1233 -6900 -4665 -2280 -6890  ...
# 1            17    s  -228 -7680 -7236 -1233 -6300 -4354 -1140 -6095  ...
# 2            18    s   228 -7680 -7236     0 -5700 -3110 -1520 -6890  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -1393                -1936                 2601
# 1                -1680                  176                 4152
# 2                 -602                 3352                 3210
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2592                -2291                 1148
# 1                  936                 1248                 3852
# 2                 -672                 2832                 3244
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9   N  Scalar_calc
# 0                 -225                -1032  58  922690295.0
# 1                  243                 -120  33  909606377.5
# 2                 -261                 1104  49  867780253.5
#
# [3 rows x 31 columns]
# LENGTH_data =  3
# LABEL =  h
# UP =  1
# DOWN =  2
# 922690295.0
# 909606377.5
# [-0.00010455584116912996, -0.002347920643798006, -0.002212181481578434, -0.0002827134915823185, -0.0019718864781897317, -0.0012835605238262929, -0.000551822495059297, -0.0020456411468507043, -0.0015496887686734498, -0.00019428431889760846, 0.0019411617353900313, 0.0020364695818358685, 0.00011227524172328357, 0.002063831417463462, 0.0013751233145577386, 0.0001433057033568119, 0.0014692847153767211, 0.0011325354199153274, 0.00028951573563498853, -0.0003873457624599055, -2.6291819709196424e-05, 0.0009602628570533251, -0.0003760341656082744, -3.8367713645397104e-05, 0.000717827821827828, -3.5769103557860254e-05, -8.254408513352366e-05, -140.04190048584454]
# ++++++++++++++++++++++++++++
# D:\ANACONDA\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# [-0.00010455584116912996,
#  -0.002347920643798006,
#  -0.002212181481578434,
#  -0.0002827134915823185,
#  -0.0019718864781897317,
#  -0.0012835605238262929,
#  -0.000551822495059297,
#  -0.0020456411468507043,
#  -0.0015496887686734498,
#  -0.00019428431889760846,
#  0.0019411617353900313,
#  0.0020364695818358685,
#  0.00011227524172328357,
#  0.002063831417463462,
#  0.0013751233145577386,
#  0.0001433057033568119,
#  0.0014692847153767211,
#  0.0011325354199153274,
#  0.00028951573563498853,
#  -0.0003873457624599055,
#  -2.6291819709196424e-05,
#  0.0009602628570533251,
#  -0.0003760341656082744,
#  -3.8367713645397104e-05,
#  0.000717827821827828,
#  -3.5769103557860254e-05,
#  -8.254408513352366e-05,
#  -140.04190048584454]

# %%
wdl.check_test('data/train_1.csv', 'all_weights/weights.txt', 'FOREST_test.csv', 'class')
# Out:
# Ошибок =  1 из  20
# Экземпляры №: ['10']

# %%
wdl.check_test('data/train_1.csv', 'all_weights/weights.txt', 'data/train_1.csv', 'class')
# Out:
# Ошибок =  0 из  180
# Экземпляры №: []
