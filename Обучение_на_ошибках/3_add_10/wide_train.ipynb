# %%
import widelearning as wdl

# %%
wdl.select_top('data/train_1.csv', 'class')
# Out:
# D:\ANACONDA\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('data/train_2.csv', 'class')
# Out:
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  7
# Количество отсеченных снизу =  10
# Количество НЕотсеченных снизу =  103
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  10
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  16
# Количество НЕотсеченных сверху =  33
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  70
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  17
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  18
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  99
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['s ']
# OTHERS -  ['o ', 'd ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  19
# Количество НЕотсеченных сверху =  25
# Количество отсеченных снизу =  11
# ...

# %%
# в качестве целевого выбираем класс 'h'

# %%
wdl.select_top('data/train_3.csv', 'class')
# Out:
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  25
# Количество отсеченных снизу =  5
# Количество НЕотсеченных снизу =  60
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  5
# TOP -  ['h ']
# OTHERS -  ['s ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  18
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  69
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['s ']
# OTHERS -  ['h ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  2
# Количество отсеченных снизу =  4
# Количество НЕотсеченных снизу =  79
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  9
# TOP -  ['o ']
# OTHERS -  ['h ', 's ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  11
# Количество НЕотсеченных сверху =  27
# Количество отсеченных снизу =  1
# ...

# %%
# в качестве целевого выбираем класс 'd'

# %%
wdl.select_top('data/train_4.csv', 'class')
# Out:
# Количество отсеченных сверху =  3
# Количество НЕотсеченных сверху =  24
# Количество отсеченных снизу =  6
# Количество НЕотсеченных снизу =  45
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  9
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  7
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  4
# Количество НЕотсеченных снизу =  67
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  11
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  4
# Количество НЕотсеченных сверху =  15
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  58
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  5
# TOP -  ['s ']
# OTHERS -  ['d ', 'o ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  21
# Количество НЕотсеченных сверху =  4
# Количество отсеченных снизу =  1
# ...

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('data/train_5.csv', 'class')
# Out:
# Количество отсеченных сверху =  27
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  3
# Количество НЕотсеченных снизу =  37
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  30
# TOP -  ['d ']
# OTHERS -  ['s ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  8
# Количество НЕотсеченных сверху =  11
# Количество отсеченных снизу =  2
# Количество НЕотсеченных снизу =  46
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  10
# TOP -  ['s ']
# OTHERS -  ['d ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  20
# Количество НЕотсеченных сверху =  1
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  45
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  21
# TOP -  ['h ']
# OTHERS -  ['d ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'd'

# %%
wdl.select_top_binary('data/train_6.csv', 'class')
# Out:
# Количество отсеченных сверху =  13
# Количество отсеченных снизу =  1
# ===Верхняя категория:  s
# ===Нижняя категория:  s
# TOP -  ['s ']
# OTHER -  ['h ']
# СУММА отсеченных сверху и снизу =  14
# [-43168.0, -136866.66666666666, -133956.0, -46237.5, -93433.33333333333, -74899.16666666667, -54382.22222222222, -120707.5, -103252.33333333333, 41091.77777777778, 118030.0, 129530.38888888889, 40356.22222222222, 98879.83333333333, 81858.72222222222, 30697.222222222223, 88856.44444444444, 77418.66666666667, -45204.83333333333, -14076.444444444443, -7007.166666666666, 4502.277777777778, -13174.999999999998, -14428.11111111111, -27092.666666666668, -9285.055555555555, -23396.5]
# DISTANCE =  6746673.777777672
# +++++++++++++++++++++++++++++++++++++++
#
# Количество отсеченных сверху =  1
# Количество отсеченных снизу =  5
# ===Верхняя категория:  s
# ===Нижняя категория:  s
# TOP -  ['h ']
# OTHER -  ['s ']
# СУММА отсеченных сверху и снизу =  6
# ...

# %%
# в качестве целевого выбираем класс 's'

# %%
wdl.select_top_binary('data/train_7.csv', 'class')
# Out:
# Количество отсеченных сверху =  17
# Количество отсеченных снизу =  4
# ===Верхняя категория:  h
# ===Нижняя категория:  s
# TOP -  ['h ']
# OTHER -  ['s ']
# СУММА отсеченных сверху и снизу =  21
# [36115.2, -35976.0, -31903.199999999983, 20495.2, -38520.0, -32468.4, 29868.0, -34821.0, -19782.800000000003, -43525.2, 29313.800000000003, 26190.0, -13598.400000000001, 39789.59999999999, 30910.4, -21074.4, 27957.199999999997, 16671.199999999997, -23562.199999999997, -35540.4, -55797.4, -36845.0, -51940.8, -64935.0, -14502.000000000002, -21307.4, -27794.199999999997]
# DISTANCE =  606798789.0000005
# +++++++++++++++++++++++++++++++++++++++
#
# Количество отсеченных сверху =  16
# Количество отсеченных снизу =  1
# ===Верхняя категория:  h
# ===Нижняя категория:  s
# TOP -  ['s ']
# OTHER -  ['h ']
# СУММА отсеченных сверху и снизу =  17
# ...

# %%
# в качестве целевого выбираем класс 'h'

# %%
wdl.select_top_binary('data/train_8.csv', 'class')
# Out:
# Количество отсеченных сверху =  1
# Количество отсеченных снизу =  1
# ===Верхняя категория:  s
# ===Нижняя категория:  h
# TOP -  ['s ']
# OTHER -  ['h ']
# СУММА отсеченных сверху и снизу =  2
# [-1368.0, -7560.0, -7452.0, -2192.0, -4800.0, -2799.0, -3230.0, -7155.0, -5754.0, 2094.0, 6635.0, 7479.0, 1919.0, 4953.0, 3060.0, 2039.0, 5098.0, 4170.0, -3028.0, -889.0, 168.0, 405.0, -1272.0, -192.0, -2084.0, -477.0, -1584.0]
# DISTANCE =  5397963.0
# +++++++++++++++++++++++++++++++++++++++
#
# Количество отсеченных сверху =  1
# Количество отсеченных снизу =  1
# ===Верхняя категория:  h
# ===Нижняя категория:  s
# TOP -  ['h ']
# OTHER -  ['s ']
# СУММА отсеченных сверху и снизу =  2
# [-2964.0, -7920.0, -7560.0, -822.0, -6600.0, -5909.0, -3420.0, -7420.0, -6576.0, 1148.0, 6410.0, 6723.0, -1096.0, 6192.0, 4563.0, -16.0, 4796.0, 4032.0, -1572.0, -742.0, -592.0, 2628.0, 864.0, 1716.0, 3384.0, 441.0, 640.0]
# DISTANCE =  83147989.0
# +++++++++++++++++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 's'

# %%
wdl.scale_weights('class', 'data/', 'weights/')
# Out:
# I =  0
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0.1 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0            38    o  -1368 -2640 -3132 -3151  4800  5909  1330  5035  ...
# 1            63    o  -2964 -2760 -3240 -2740  7500  8086 -4180   795  ...
# 2            82    o  -1824 -3000 -3348 -2740  6300  6531 -2090  1325  ...
# 3            90    o   2736   720   432   548  5700  5909 -1330 -1325  ...
# 4           136    o  -3648 -3000 -2592 -5069  5100  6220 -7980  1325  ...
#
# ...

# %%
wdl.check_test('data/train_1.csv', 'all_weights/weights.txt', 'FOREST_test.csv', 'class')
# Out:
# Ошибок =  1 из  20
# Экземпляры №: ['125']

# %%
wdl.check_test('data/train_1.csv', 'all_weights/weights.txt', 'data/train_1.csv', 'class')
# Out:
# Ошибок =  0 из  181
# Экземпляры №: []
