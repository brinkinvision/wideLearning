# %%
import widelearning as wdl

# %%
wdl.select_top('FOREST_train.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  3
# Количество НЕотсеченных сверху =  46
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  132
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  4
# TOP -  ['d ']
# OTHERS -  ['h ', 's ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  6
# Количество НЕотсеченных сверху =  38
# Количество отсеченных снизу =  15
# Количество НЕотсеченных снизу =  123
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  21
# TOP -  ['h ']
# OTHERS -  ['d ', 's ', 'o ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  12
# Количество НЕотсеченных сверху =  41
# Количество отсеченных снизу =  28
# Количество НЕотсеченных снизу =  101
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  40
# TOP -  ['s ']
# OTHERS -  ['d ', 'h ', 'o ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  29
# Количество НЕотсеченных сверху =  7
# Количество отсеченных снизу =  32
# Количество НЕотсеченных снизу =  114
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  61
# TOP -  ['o ']
# OTHERS -  ['d ', 'h ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('train_2.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  7
# Количество отсеченных снизу =  10
# Количество НЕотсеченных снизу =  104
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  10
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  16
# Количество НЕотсеченных сверху =  33
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  71
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  17
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  19
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  99
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['s ']
# OTHERS -  ['o ', 'd ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  22
# Количество НЕотсеченных сверху =  22
# Количество отсеченных снизу =  11
# Количество НЕотсеченных снизу =  66
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  33
# TOP -  ['h ']
# OTHERS -  ['o ', 'd ', 's ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'h'

# %%
wdl.select_top('train_3.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  22
# Количество отсеченных снизу =  7
# Количество НЕотсеченных снизу =  59
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  7
# TOP -  ['h ']
# OTHERS -  ['s ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  19
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  66
# ===Нижняя категория:  o
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['s ']
# OTHERS -  ['h ', 'o ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  2
# Количество отсеченных снизу =  3
# Количество НЕотсеченных снизу =  78
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  8
# TOP -  ['o ']
# OTHERS -  ['h ', 's ', 'd ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  10
# Количество НЕотсеченных сверху =  28
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  49
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  11
# TOP -  ['d ']
# OTHERS -  ['h ', 's ', 'o ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('train_4.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# Количество отсеченных сверху =  1
# Количество НЕотсеченных сверху =  1
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  77
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  2
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  31
# Количество НЕотсеченных сверху =  7
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  41
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  32
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  19
# Количество отсеченных снизу =  3
# Количество НЕотсеченных снизу =  56
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  5
# TOP -  ['s ']
# OTHERS -  ['o ', 'd ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  19
# Количество отсеченных снизу =  5
# Количество НЕотсеченных снизу =  56
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  5
# TOP -  ['h ']
# OTHERS -  ['o ', 'd ', 's ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1

# %%
# в качестве целевого выбираем класс 'd'

# %%
wdl.select_top('train_5.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  5
# Количество НЕотсеченных сверху =  2
# Количество отсеченных снизу =  4
# Количество НЕотсеченных снизу =  37
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  9
# TOP -  ['d ']
# OTHERS -  ['o ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  2
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  18
# Количество НЕотсеченных снизу =  28
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  20
# TOP -  ['o ']
# OTHERS -  ['d ', 's ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  12
# Количество НЕотсеченных сверху =  8
# Количество отсеченных снизу =  12
# Количество НЕотсеченных снизу =  16
# ===Нижняя категория:  h
# СУММА отсеченных сверху и снизу =  24
# TOP -  ['s ']
# OTHERS -  ['d ', 'o ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  18
# Количество НЕотсеченных сверху =  1
# Количество отсеченных снизу =  1
# Количество НЕотсеченных снизу =  28
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  19
# TOP -  ['h ']
# OTHERS -  ['d ', 'o ', 's ']
# +++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1

# %%
# в качестве целевого выбираем класс 'o'

# %%
wdl.select_top('train_6.csv', 'class')
# Out:
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# Количество отсеченных сверху =  13
# Количество НЕотсеченных сверху =  7
# Количество отсеченных снизу =  7
# Количество НЕотсеченных снизу =  1
# ===Нижняя категория:  d
# СУММА отсеченных сверху и снизу =  20
# TOP -  ['s ']
# OTHERS -  ['d ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  7
# Количество НЕотсеченных сверху =  0
# Количество отсеченных снизу =  3
# Количество НЕотсеченных снизу =  18
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  10
# TOP -  ['d ']
# OTHERS -  ['s ', 'h ']
# +++++++++++++++++++++++++
# Количество отсеченных сверху =  0
# Количество НЕотсеченных сверху =  1
# Количество отсеченных снизу =  3
# Количество НЕотсеченных снизу =  24
# ===Нижняя категория:  s
# СУММА отсеченных сверху и снизу =  3
# TOP -  ['h ']
# OTHERS -  ['s ', 'd ']
# +++++++++++++++++++++++++

# %%
# в качестве целевого выбираем класс 'd'

# %%
wdl.select_top_binary('train_7.csv', 'class')
# Out:
# Количество отсеченных сверху =  17
# Количество отсеченных снизу =  1
# ===Верхняя категория:  s
# ===Нижняя категория:  h
# TOP -  ['s ']
# OTHER -  ['h ']
# СУММА отсеченных сверху и снизу =  18
# [7752.0, -3120.0, -6372.0, -30825.0, 13800.0, 21148.0, 2090.0, 2650.0, 4110.0, 21808.0, 9739.0, 16403.0, 56587.0, -2592.0, 5957.0, 30580.0, 9092.0, 11672.0, -29507.0, -13693.0, -14736.0, -48830.0, -38567.0, -55582.0, -86731.0, -27620.0, -46448.0]
# DISTANCE =  836098690.0
# +++++++++++++++++++++++++++++++++++++++
#
# Количество отсеченных сверху =  14
# Количество отсеченных снизу =  3
# ===Верхняя категория:  s
# ===Нижняя категория:  s
# TOP -  ['h ']
# OTHER -  ['s ']
# СУММА отсеченных сверху и снизу =  17
# [-40302.352941176476, -130122.35294117648, -127401.88235294117, -42212.11764705882, -92999.99999999999, -74987.58823529411, -52954.117647058825, -116662.35294117648, -101734.58823529411, 38960.70588235294, 112103.17647058822, 123401.58823529411, 35657.882352941175, 96996.70588235295, 78883.0, 28524.235294117647, 85575.29411764706, 75734.58823529411, -53015.76470588235, -24803.176470588234, -23376.0, -3755.058823529411, -22423.529411764706, -24755.529411764706, -27286.11764705882, -18913.352941176472, -33438.117647058825]
# DISTANCE =  46510588.764707565
# +++++++++++++++++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1478: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_classes_allcut.drop(all_classes_allcut.columns[0], axis=1, inplace=True)
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'] = ""
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1478: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_top['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_classes['Scalar_calc'][j]=scalar1
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:1534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_classes_allcut.drop(all_classes_allcut.columns[0], axis=1, inplace=True)

# %%
# в качестве целевого выбираем класс 's'

# %%
wdl.scale_weights('class', 'data/', 'weights/')
# Out:
# I =  0
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0          38    o  -1368 -2640 -3132 -3151  4800  5909  1330  5035  ...
# 1          63    o  -2964 -2760 -3240 -2740  7500  8086 -4180   795  ...
# 2          82    o  -1824 -3000 -3348 -2740  6300  6531 -2090  1325  ...
# 3          90    o   2736   720   432   548  5700  5909 -1330 -1325  ...
# 4         136    o  -3648 -3000 -2592 -5069  5100  6220 -7980  1325  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -1498                 -512                  -51
# 1                -2030                -2160                -1377
# 2                -1785                 -328                 -423
# 3                -1099                 -464                 1011
# 4                -1183                 -319                 -369
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2184                -2280                 -340
# 1                -1776                -2591                -2144
# 2                -1296                 -876                 -663
# 3                -2088                -1020                  112
# 4                -1488                 -888                -2236
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                 -414                -1424   38  7.180349e+09
# 1                -1917                -2576   63  6.514290e+09
# 2                 -648                -1216   82  6.064096e+09
# 3                 -630                 -960   90  5.449081e+09
# 4                -1007                -1856  136  4.934307e+09
#
# [5 rows x 31 columns]
# LENGTH_data =  182
# LABEL =  o
# UP =  29
# DOWN =  32
# -4042725449.527397
# -13505565180.431503
# [5.345622303850924e-06, 2.8801571756959988e-05, 2.4494312491384873e-05, 3.210872578081459e-06, 5.200500932991418e-05, 4.9615046458348404e-05, 3.254923764292204e-06, 3.786485360474943e-05, 4.314905034391765e-05, -4.248520490297848e-06, -2.384119683658419e-05, -2.2055046455180063e-05, -3.055004049600245e-06, -5.181628553616057e-05, -4.7205943107516154e-05, -2.0629533856016007e-06, -2.892462265838246e-05, -3.160349066745895e-05, 1.1274526899939042e-06, 2.4783316067300335e-07, 1.2538736591619737e-06, 1.1167113228666064e-06, 2.329744624967207e-06, 2.948432895263648e-06, 2.1331081206047254e-06, 6.798445769891473e-07, 2.9208701418803897e-07, 1.8544423374992833]
# ++++++++++++++++++++++++++++
#
# I =  1
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6   b7    b8  ...  \
# 0          91    h   5244 -7440 -6912  1096 -6900 -4665  950 -7155  ...
# 1          89    h   3648 -7440 -6912   548 -6600 -4976 -570 -6890  ...
# 2         111    h   2736 -7680 -7452   411 -7500 -6220 -950 -7420  ...
# 3          93    h   2964 -7440 -7020     0 -6900 -4976  380 -7155  ...
# 4          98    h   3192 -7680 -7236   822 -7200 -5598  190 -6890  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -2303                -3200                 -525
# 1                -2821                -3664                  -78
# 2                 -616                -1016                 -144
# 3                -1862                -3856                 1149
# 4                -1274                 -936                 -945
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2544                -4248                -4324
# 1                -4224                -5448                -2148
# 2                -2016                -1920                -2400
# 3                -2856                -5160                -1016
# 4                -3072                -1716                -2948
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -2853                -4504  178  6.181598e+09
# 1                -1107                -2712  171  5.800020e+09
# 2                 2025                  920  104  5.673741e+09
# 3                -2267                -3032  184  5.592916e+09
# 4                 -954                 -760  117  5.509912e+09
#
# [5 rows x 31 columns]
# LENGTH_data =  121
# LABEL =  h
# UP =  22
# DOWN =  11
# 4992134138.714287
# -91021787.64285602
# [8.704243822623968e-05, -2.8207448132643233e-05, -1.6839482307019873e-05, 3.6677495491475007e-05, -5.2273487094209706e-05, -3.4524389903699954e-05, 1.208922753142218e-05, -7.805049911722578e-06, 8.824776366414096e-06, -8.013362568195498e-05, 2.1792648145424115e-05, 1.219950772677578e-05, -2.8596126802811464e-05, 5.098564823797042e-05, 2.9372641022388358e-05, -7.443519730012906e-06, 5.6746523764056255e-06, -7.239596922294851e-06, -1.3665863351844294e-06, -2.387268326736858e-06, -5.1878906578724425e-06, -3.6493638957835052e-06, -1.0865465852911278e-05, -1.0059386198698314e-05, 8.222113647463425e-07, 2.9734620868503053e-06, 2.0263002255336132e-06, -0.9641868992564676]
# ++++++++++++++++++++++++++++
#
# I =  2
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0          56    o   -456 -5280 -5724  -411   300  1555 -2850 -4505  ...
# 1          45    o  -1140 -4800 -5400 -2055   300  -311 -1710 -3710  ...
# 2           9    o  -1824 -3240 -4104  4247 -3900     0  8170 -3445  ...
# 3          61    o  -2052 -5520 -5184   137  -600  1866  -760 -5830  ...
# 4          11    o   1140 -6240 -6480  -411 -1500     0  2850 -5830  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                 -826                   64                 -129
# 1                -3010                -4808                 -249
# 2                -2520                 -776                 -411
# 3                -1603                -1304                 -255
# 4                 -938                 -360                 -366
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -1344                 -912                -2544
# 1                -3816                -4728                -2616
# 2                -2640                -2052                 -440
# 3                -1536                 -924                -1699
# 4                -1440                -1032                -2812
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                 -558                -1800  154 -3.337497e+08
# 1                -4058                -4720   12 -3.342194e+08
# 2                -2313                -2608   92 -3.457632e+08
# 3                -1179                -1776  122 -4.115449e+08
# 4                 -792                -2031  157 -4.921951e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  88
# LABEL =  o
# UP =  5
# DOWN =  3
# -496375866.44444424
# -1065223733.8271604
# [-3.483584528051693e-06, 3.321593680530148e-05, 2.3828280712437283e-05, 4.239932469654813e-06, 6.0603328325181525e-05, 5.6926283666528686e-05, 1.402010818581409e-06, 6.524255173973198e-05, 7.994621615994301e-05, 8.420963122566143e-06, -2.7267374185100563e-05, -2.0667939978997857e-05, -5.985414235834826e-06, -6.234464312422271e-05, -5.8819128489336684e-05, -1.1025100554788692e-07, -5.027376403531373e-05, -5.9186559497983465e-05, -8.68643365403499e-06, -1.543514077670396e-07, -1.6461256434638136e-06, -4.0397878292684767e-07, -5.20962044758388e-06, 2.936105814281801e-06, -9.904012770816015e-06, -1.0199476784502822e-05, -9.578294839465094e-06, 2.7451972483549336]
# ++++++++++++++++++++++++++++
#
# I =  3
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0           1    d  -2736 -4440 -5400 -1507  -300  -622  5700 -6360  ...
# 1           2    d  -1824 -5040 -5616 -3014   600 -1555  2850 -6360  ...
# 2           4    d  -2736 -5160 -5940 -1370 -2100 -1244  3420 -6095  ...
# 3           8    d  -3420 -5040 -5616 -1644 -2100  -933  1520 -6625  ...
# 4           3    d  -2964 -5160 -5616     0 -2400   311  2470 -6625  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -2688                -2368                -1305
# 1                -3164                -4656                 -326
# 2                -2429                -2160                -1350
# 3                -1337                 -840                 -945
# 4                -3276                -2896                 -197
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -2592                -3828                -2824
# 1                -3984                -4872                -2260
# 2                -2232                -3720                -3036
# 3                -2160                -1716                -3060
# 4                -2352                -1980                 -563
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -3240                -4152   24  8.299144e+08
# 1                -3501                -4128   21  3.484253e+08
# 2                -2457                -3456    4 -1.143713e+08
# 3                -1413                -2416  146 -1.224516e+08
# 4                -2304                -2695  110 -1.301954e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  80
# LABEL =  d
# UP =  31
# DOWN =  1
# -1206898724.4761915
# -4463190614.333334
# [-6.325652651941806e-05, 4.9774407664391124e-05, 3.4152080531706216e-05, -2.957088363956616e-06, 6.27356886899585e-05, 5.13920817629653e-05, 5.7965144082863314e-05, -2.301917192700795e-06, -2.3472389750755888e-05, 5.9514700969801646e-05, -4.358393067957624e-05, -3.323113817018201e-05, 5.578679718606697e-06, -6.308262143552507e-05, -4.818548376720728e-05, -2.7314650897090888e-05, 1.6075544956432881e-06, 1.745286386169525e-05, -1.4540553278337385e-05, -1.0060376931062226e-05, -1.3305581504475617e-05, -2.116620243658718e-05, -1.790084639953399e-05, -2.670454998050696e-05, -2.0656888085609595e-05, -1.463317981730293e-05, -1.4882279985401938e-05, 1.7412718302284258]
# ++++++++++++++++++++++++++++
#
# I =  4
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0          17    o  -3876 -5160 -5832 -8083 -5400 -7153 -6460   265  ...
# 1           0    o  -5472 -5880 -6372 -2329 -2400 -2799 -1140 -5565  ...
# 2          24    s  -2736 -6840 -6696 -2603 -1500 -2488 -1140 -5035  ...
# 3           4    d  -3192 -3720 -3348 -5206 -4800 -5909 -2280 -7155  ...
# 4           1    d  -5244 -5400 -5292 -4384 -4200 -4976 -1520 -6625  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -2485                -2464                  336
# 1                 -840                 -624                  618
# 2                 7441                 7432                 4626
# 3                -2310                -3040                  153
# 4                -1736                -3200                  453
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -3264                -3072                 -644
# 1                 -672                  684                 1564
# 2                 8064                 7608                 -640
# 3                -3024                -3384                -1027
# 4                -2496                -2532                 -824
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -1404                -2024   56  8.802130e+07
# 1                 -846                 -896   61 -9.417102e+07
# 2                 7965                 7448  123 -1.222114e+08
# 3                -1143                -1880  193 -1.292162e+08
# 4                 -801                -1264  161 -1.313822e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  48
# LABEL =  o
# UP =  2
# DOWN =  18
# -108191218.69565214
# -231268260.36956516
# [-0.00011501597612706466, 5.536299013045344e-05, 2.876671141081605e-05, -0.00012070135108341686, 4.853799670702084e-05, -2.8125190289855704e-05, -7.369721159402253e-05, 0.00013349362136547393, 0.00011886227676859336, 8.525942871353339e-05, -5.497087094308238e-05, -4.024202644015274e-05, 7.095944249300788e-05, -5.691662993771316e-05, 3.748800735479646e-06, 2.4398998228242486e-05, -0.00010603891955996992, -9.3705887965825e-05, 1.3591345599024199e-05, -2.714453906089871e-06, -7.564014450442005e-06, 1.3710747657881328e-05, -7.52939491858401e-06, 1.6028136729191784e-05, 4.2684469738786985e-05, -7.313905995794471e-06, 6.860319476348958e-06, 2.7581056096928265]
# ++++++++++++++++++++++++++++
#
# I =  5
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0           1    d  -3192 -3720 -3348 -5206 -4800 -5909 -2280 -7155  ...
# 1           3    d  -2508 -3600 -3780 -3836 -3000 -5287 -1520 -7155  ...
# 2           2    d  -5244 -5400 -5292 -4384 -4200 -4976 -1520 -6625  ...
# 3          11    d  -4332 -6360 -6372  -685 -4800 -2799  -190 -6625  ...
# 4          13    d  -3648 -5640 -5940 -1507 -4800 -3110 -1330 -6890  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                -2310                -3040                  153
# 1                -1414                -1368                  804
# 2                -1736                -3200                  453
# 3                -2436                -2416                -1629
# 4                -1596                -1304                 -969
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -3024                -3384                -1027
# 1                -1944                -2064                 2064
# 2                -2496                -2532                 -824
# 3                -2784                -3828                -2220
# 4                -2568                -2891                -1444
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -1143                -1880  193 -1.070260e+08
# 1                -1593                -1696  186 -1.210845e+08
# 2                 -801                -1264  161 -1.608422e+08
# 3                -1620                -2599   27 -2.045272e+08
# 4                 -477                -1200  145 -2.186856e+08
#
# [5 rows x 31 columns]
# LENGTH_data =  28
# LABEL =  d
# UP =  7
# DOWN =  3
# -275510298.6666665
# -549001199.4999998
# [-0.00011615742938138764, 0.00011525063504474121, 0.00010319904579640786, 3.339538282810773e-07, 4.8996145609122216e-05, 4.017927701866471e-05, 5.279883153699436e-05, -1.9379072517040875e-06, -3.9406551737167626e-05, 5.9002572361632016e-05, -0.00011246199869763493, -0.00011673026988975292, -6.8594603852770966e-06, -4.910583847242622e-05, -3.927492030120282e-05, -3.925541934772658e-05, -1.8038381965547304e-06, 2.5599876675970205e-05, 3.1247840326534215e-05, -3.854363454584281e-05, -5.6591766988128426e-05, -2.781323489552659e-05, -9.284647711969434e-05, -0.00010863006133954839, 2.1728937410931105e-05, -1.7246155730574114e-05, -2.066369782729001e-05, 3.014767568699215]
# ++++++++++++++++++++++++++++
#
# I =  6
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']
#    Unnamed: 0 class    b1    b2    b3    b4    b5    b6    b7    b8  ...  \
# 0           0    s  -2964 -7800 -7560 -2740 -3300 -2799 -4750 -7155  ...
# 1           2    s  -2964 -7920 -7560 -2329 -4800 -3421 -4560 -7685  ...
# 2           3    s  -4104 -7320 -7128 -4521 -5700 -6220 -2660 -6890  ...
# 3           1    s  -1140 -7800 -7560 -1918 -6300 -4354 -1330 -6625  ...
# 4           5    s  -2280 -7680 -7560 -2740 -4200 -3732 -1900 -6625  ...
#
#    pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# 0                  167                  736                -4761
# 1                 -280                 -576                -2556
# 2                  112                -2096                  129
# 3                -5614                -7128                  270
# 4                -1449                -2120                  191
#
#    pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# 0                -5111                -5448                -5344
# 1                -5040                -3828                -4024
# 2                -1776                -4140                -5036
# 3                -4440                -4020                 -264
# 4                -2496                -1344                -3204
#
#    pred_minus_obs_S_b8  pred_minus_obs_S_b9    N   Scalar_calc
# 0                -2664                -3000  190  2.093497e+09
# 1                -2925                -3544  185  1.773738e+09
# 2                  792                  168   51  1.457082e+09
# 3                -4194                -4104  130  1.374225e+09
# 4                -1287                -2208  167  1.281640e+09
#
# [5 rows x 31 columns]
# LENGTH_data =  18
# LABEL =  s
# UP =  17
# DOWN =  1
# 351329352.0
# -484769338.0
# [1.8543265508525076e-05, -7.463233796000805e-06, -1.5242219791063182e-05, -7.373531466721948e-05, 3.3010457174618946e-05, 5.058732958904648e-05, 4.999409818474898e-06, 6.338964602372478e-06, 9.831375288962598e-06, 5.2166090584354343e-05, 2.3296292929247382e-05, 3.923699485762859e-05, 0.00013535961885073638, -6.200224999754515e-06, 1.424951401371051e-05, 7.314925944926429e-05, 2.1748628741422857e-05, 2.7920148995808137e-05, -7.058257680083197e-05, -3.275450652840994e-05, -3.524942731341919e-05, -0.0001168043930316408, -9.225465955460353e-05, -0.00013295559642606305, -0.00020746593921825186, -6.606875559151994e-05, -0.00011110650107584788, 0.15959836750850553]
# ++++++++++++++++++++++++++++
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# D:\ANACONDA\envs\tf\lib\site-packages\widelearning.py:2308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Scalar_calc'][i]=scalar
# [1.8543265508525076e-05,
#  -7.463233796000805e-06,
#  -1.5242219791063182e-05,
#  -7.373531466721948e-05,
#  3.3010457174618946e-05,
#  5.058732958904648e-05,
#  4.999409818474898e-06,
#  6.338964602372478e-06,
#  9.831375288962598e-06,
#  5.2166090584354343e-05,
#  2.3296292929247382e-05,
#  3.923699485762859e-05,
#  0.00013535961885073638,
#  -6.200224999754515e-06,
#  1.424951401371051e-05,
#  7.314925944926429e-05,
#  2.1748628741422857e-05,
#  2.7920148995808137e-05,
#  -7.058257680083197e-05,
#  -3.275450652840994e-05,
#  -3.524942731341919e-05,
#  -0.0001168043930316408,
#  -9.225465955460353e-05,
#  -0.00013295559642606305,
#  -0.00020746593921825186,
#  -6.606875559151994e-05,
#  -0.00011110650107584788,
#  0.15959836750850553]

# %%
wdl.check_test('data/train_1.csv', 'all_weights/weights.txt', 'FOREST_test.csv', 'class')
# Out:
# Ошибок =  0 из  20
# Экземпляры №: []

# %%
wdl.check_test('data/train_1.csv', 'all_weights/weights.txt', 'data/train_1.csv', 'class')
# Out:
# Ошибок =  0 из  182
# Экземпляры №: []
